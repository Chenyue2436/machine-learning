# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Keyring is skipped due to an exception: Failed to create the collection: Prompt dismissed..
# ...
#      |████████████████████████████████| 27.3 MB 3.8 MB/s eta 0:00:011
# ...
#      |███████████▋                    | 301.7 MB 1.2 MB/s eta 0:07:079   |█▋                              | 43.0 MB 3.7 MB/s eta 0:03:31     |████████▌                       | 220.1 MB 8.4 MB/s eta 0:01:13     |████████▊                       | 227.4 MB 6.3 MB/s eta 0:01:37
