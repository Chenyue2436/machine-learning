# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scipy==1.6.1
#   Downloading scipy-1.6.1-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
#      |████████████████████████████████| 27.4 MB 118 kB/s eta 0:00:01    |███▍                            | 2.9 MB 778 kB/s eta 0:00:32
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |██▊                             | 72.0 MB 123 kB/s eta 1:42:13^C  |▏                               | 2.9 MB 278 kB/s eta 0:49:40
#
# ERROR: Operation cancelled by user

# %%
# !python -u train.py ETTh1 forecast_univar --alpha 0.0005 --kernels 1 2 4 8 16 32 64 128 --max-train-length 201 --batch-size 128 --archive forecast_csv_univar --repr-dims 320 --max-threads 8 --seed 1 --eval
# Out:
# Traceback (most recent call last):
#   File "train.py", line 12, in <module>
#     from cost import CoST
#   File "/home/chenyue/study python/CoST-main/cost.py", line 11, in <module>
#     from einops import rearrange, repeat, reduce
# ModuleNotFoundError: No module named 'einops'
